# %%
import gym
import numpy as np
from ppo import Agent
import wandb

# %%
env = gym.make('CartPole-v1')
N = 30
batch_size = 5
n_epochs = 4
alpha = 0.0002
agent = Agent(n_actions = env.action_space.n, 
              batch_size = batch_size, 
              alpha = alpha, 
              n_epochs=n_epochs, 
              input_dims=env.observation_space.shape)
n_games = 200

# %%
figure_file = 'plots/cartpole.png'

best_score = env.reward_range[0]
best_score
# Out:
# -inf

# %%
score_history = []
learn_iters = 0
avg_score = 0
n_steps = 0
max_time_steps = 500

# %%
run = wandb.init(
    entity="ducanh2002add-hanoi-university-of-science-and-technology",
    project="PPO-testing",
    config={
        "learning_rate": alpha,
        "architecture": "PPO",
        "dataset": "Gym CartPole-v1",
        "epochs": n_epochs,
        "batch_size": batch_size,
        "Number of games": n_games,
        "Total timestep to start learning (n_steps)": N,
        "Agent's hidden size1": 256,
        "Agent's hidden_size2": 256,
        "Environment maximum steps": max_time_steps

    }
)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ducanh2002add (ducanh2002add-hanoi-university-of-science-and-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>d:\Reinforcement Learning\rl-ntm\ppo_trainer\wandb\run-20250404_234118-er43r99r</code>
# Syncing run <strong><a href='https://wandb.ai/ducanh2002add-hanoi-university-of-science-and-technology/PPO-testing/runs/er43r99r' target="_blank">hopeful-river-6</a></strong> to <a href='https://wandb.ai/ducanh2002add-hanoi-university-of-science-and-technology/PPO-testing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ducanh2002add-hanoi-university-of-science-and-technology/PPO-testing' target="_blank">https://wandb.ai/ducanh2002add-hanoi-university-of-science-and-technology/PPO-testing</a>
#  View run at <a href='https://wandb.ai/ducanh2002add-hanoi-university-of-science-and-technology/PPO-testing/runs/er43r99r' target="_blank">https://wandb.ai/ducanh2002add-hanoi-university-of-science-and-technology/PPO-testing/runs/er43r99r</a>

# %%
for i in range(n_games):
    observation = env.reset()[0]
    done = False
    score = 0
    n_steps = 0
    while not done and n_steps < max_time_steps:
        # print(observation[0])
        action, prob, val = agent.choose_action(observation)
        observation_, reward, done, _, _ = env.step(action)
        n_steps += 1
        score += reward

        agent.remember(observation, action, prob, val, reward, done)
        if n_steps % N == 0:
            agent.learn()
            learn_iters += 1
        
        observation = observation_

    score_history.append(score)
    avg_score = np.mean(score_history)

    if avg_score > best_score:
        best_score = avg_score
        agent.save_models()

    print(f"Episode {i:5} | score: {score:5} | Avg_score: {avg_score:7.2f} | Time_steps: {n_steps:7} | Learning_steps: {learn_iters}")
    
    run.log({
        "score" : score,
        "avg_score": avg_score,
        "best_score": best_score
    })
# Out:
# d:\Reinforcement Learning\rl-ntm\ppo_trainer\ppo.py:141: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   state = torch.tensor([observation], dtype = torch.float).to(self.actor.device)
# Saving models
# Episode     0 | score:  11.0 | Avg_score:   11.00 | Time_steps:      11 | Learning_steps: 0
# Saving models
# Episode     1 | score:  13.0 | Avg_score:   12.00 | Time_steps:      13 | Learning_steps: 0
# Saving models
# Episode     2 | score:  21.0 | Avg_score:   15.00 | Time_steps:      21 | Learning_steps: 0
# Episode     3 | score:  15.0 | Avg_score:   15.00 | Time_steps:      15 | Learning_steps: 0
# Saving models
# Episode     4 | score:  30.0 | Avg_score:   18.00 | Time_steps:      30 | Learning_steps: 1
# Episode     5 | score:  15.0 | Avg_score:   17.50 | Time_steps:      15 | Learning_steps: 1
# Saving models
# Episode     6 | score:  25.0 | Avg_score:   18.57 | Time_steps:      25 | Learning_steps: 1
# Episode     7 | score:  17.0 | Avg_score:   18.38 | Time_steps:      17 | Learning_steps: 1
# Episode     8 | score:  20.0 | Avg_score:   18.56 | Time_steps:      20 | Learning_steps: 1
# Saving models
# Episode     9 | score:  28.0 | Avg_score:   19.50 | Time_steps:      28 | Learning_steps: 1
# Episode    10 | score:  11.0 | Avg_score:   18.73 | Time_steps:      11 | Learning_steps: 1
# Episode    11 | score:  21.0 | Avg_score:   18.92 | Time_steps:      21 | Learning_steps: 1
# Saving models
# Episode    12 | score:  29.0 | Avg_score:   19.69 | Time_steps:      29 | Learning_steps: 1
# Episode    13 | score:  16.0 | Avg_score:   19.43 | Time_steps:      16 | Learning_steps: 1
# Episode    14 | score:  11.0 | Avg_score:   18.87 | Time_steps:      11 | Learning_steps: 1
# Episode    15 | score:  11.0 | Avg_score:   18.38 | Time_steps:      11 | Learning_steps: 1
# Episode    16 | score:  27.0 | Avg_score:   18.88 | Time_steps:      27 | Learning_steps: 1
# Episode    17 | score:  10.0 | Avg_score:   18.39 | Time_steps:      10 | Learning_steps: 1
# Episode    18 | score:  15.0 | Avg_score:   18.21 | Time_steps:      15 | Learning_steps: 1
# Episode    19 | score:  38.0 | Avg_score:   19.20 | Time_steps:      38 | Learning_steps: 2
# Episode    20 | score:  14.0 | Avg_score:   18.95 | Time_steps:      14 | Learning_steps: 2
# Episode    21 | score:  13.0 | Avg_score:   18.68 | Time_steps:      13 | Learning_steps: 2
# Episode    22 | score:  17.0 | Avg_score:   18.61 | Time_steps:      17 | Learning_steps: 2
# Episode    23 | score:  30.0 | Avg_score:   19.08 | Time_steps:      30 | Learning_steps: 3
# Episode    24 | score:  34.0 | Avg_score:   19.68 | Time_steps:      34 | Learning_steps: 4
# Saving models
# Episode    25 | score:  51.0 | Avg_score:   20.88 | Time_steps:      51 | Learning_steps: 5
# Saving models
# Episode    26 | score:  23.0 | Avg_score:   20.96 | Time_steps:      23 | Learning_steps: 5
# Saving models
# Episode    27 | score:  41.0 | Avg_score:   21.68 | Time_steps:      41 | Learning_steps: 6
# Episode    28 | score:  16.0 | Avg_score:   21.48 | Time_steps:      16 | Learning_steps: 6
# Episode    29 | score:  21.0 | Avg_score:   21.47 | Time_steps:      21 | Learning_steps: 6
# Episode    30 | score:  14.0 | Avg_score:   21.23 | Time_steps:      14 | Learning_steps: 6
# Episode    31 | score:  31.0 | Avg_score:   21.53 | Time_steps:      31 | Learning_steps: 7
# Saving models
# Episode    32 | score:  28.0 | Avg_score:   21.73 | Time_steps:      28 | Learning_steps: 7
# Episode    33 | score:  15.0 | Avg_score:   21.53 | Time_steps:      15 | Learning_steps: 7
# Episode    34 | score:  20.0 | Avg_score:   21.49 | Time_steps:      20 | Learning_steps: 7
# Episode    35 | score:  15.0 | Avg_score:   21.31 | Time_steps:      15 | Learning_steps: 7
# Episode    36 | score:  19.0 | Avg_score:   21.24 | Time_steps:      19 | Learning_steps: 7
# Saving models
# Episode    37 | score:  50.0 | Avg_score:   22.00 | Time_steps:      50 | Learning_steps: 8
# Saving models
# Episode    38 | score:  25.0 | Avg_score:   22.08 | Time_steps:      25 | Learning_steps: 8
# Episode    39 | score:  14.0 | Avg_score:   21.88 | Time_steps:      14 | Learning_steps: 8
# Episode    40 | score:  24.0 | Avg_score:   21.93 | Time_steps:      24 | Learning_steps: 8
# Episode    41 | score:  23.0 | Avg_score:   21.95 | Time_steps:      23 | Learning_steps: 8
# Saving models
# Episode    42 | score:  29.0 | Avg_score:   22.12 | Time_steps:      29 | Learning_steps: 8
# Episode    43 | score:  21.0 | Avg_score:   22.09 | Time_steps:      21 | Learning_steps: 8
# Saving models
# Episode    44 | score:  33.0 | Avg_score:   22.33 | Time_steps:      33 | Learning_steps: 9
# Episode    45 | score:  21.0 | Avg_score:   22.30 | Time_steps:      21 | Learning_steps: 9
# Saving models
# Episode    46 | score:  27.0 | Avg_score:   22.40 | Time_steps:      27 | Learning_steps: 9
# Saving models
# Episode    47 | score:  37.0 | Avg_score:   22.71 | Time_steps:      37 | Learning_steps: 10
# Episode    48 | score:  19.0 | Avg_score:   22.63 | Time_steps:      19 | Learning_steps: 10
# Episode    49 | score:  22.0 | Avg_score:   22.62 | Time_steps:      22 | Learning_steps: 10
# Episode    50 | score:  14.0 | Avg_score:   22.45 | Time_steps:      14 | Learning_steps: 10
# Episode    51 | score:  34.0 | Avg_score:   22.67 | Time_steps:      34 | Learning_steps: 11
# Saving models
# Episode    52 | score:  41.0 | Avg_score:   23.02 | Time_steps:      41 | Learning_steps: 12
# Saving models
# Episode    53 | score:  95.0 | Avg_score:   24.35 | Time_steps:      95 | Learning_steps: 15
# Saving models
# Episode    54 | score:  49.0 | Avg_score:   24.80 | Time_steps:      49 | Learning_steps: 16
# Episode    55 | score:  17.0 | Avg_score:   24.66 | Time_steps:      17 | Learning_steps: 16
# Saving models
# Episode    56 | score:  46.0 | Avg_score:   25.04 | Time_steps:      46 | Learning_steps: 17
# Saving models
# Episode    57 | score:  34.0 | Avg_score:   25.19 | Time_steps:      34 | Learning_steps: 18
# Episode    58 | score:  18.0 | Avg_score:   25.07 | Time_steps:      18 | Learning_steps: 18
# Episode    59 | score:  25.0 | Avg_score:   25.07 | Time_steps:      25 | Learning_steps: 18
# Episode    60 | score:  20.0 | Avg_score:   24.98 | Time_steps:      20 | Learning_steps: 18
# Saving models
# Episode    61 | score: 129.0 | Avg_score:   26.66 | Time_steps:     129 | Learning_steps: 22
# Saving models
# Episode    62 | score:  27.0 | Avg_score:   26.67 | Time_steps:      27 | Learning_steps: 22
# Saving models
# Episode    63 | score: 112.0 | Avg_score:   28.00 | Time_steps:     112 | Learning_steps: 25
# Saving models
# Episode    64 | score:  94.0 | Avg_score:   29.02 | Time_steps:      94 | Learning_steps: 28
# Saving models
# Episode    65 | score: 147.0 | Avg_score:   30.80 | Time_steps:     147 | Learning_steps: 32
# Saving models
# Episode    66 | score:  96.0 | Avg_score:   31.78 | Time_steps:      96 | Learning_steps: 35
# Saving models
# Episode    67 | score:  48.0 | Avg_score:   32.01 | Time_steps:      48 | Learning_steps: 36
# Saving models
# Episode    68 | score: 168.0 | Avg_score:   33.99 | Time_steps:     168 | Learning_steps: 41
# Saving models
# Episode    69 | score:  39.0 | Avg_score:   34.06 | Time_steps:      39 | Learning_steps: 42
# Saving models
# Episode    70 | score: 307.0 | Avg_score:   37.90 | Time_steps:     307 | Learning_steps: 52
# Saving models
# Episode    71 | score: 150.0 | Avg_score:   39.46 | Time_steps:     150 | Learning_steps: 57
# Saving models
# Episode    72 | score: 202.0 | Avg_score:   41.68 | Time_steps:     202 | Learning_steps: 63
# Saving models
# Episode    73 | score: 114.0 | Avg_score:   42.66 | Time_steps:     114 | Learning_steps: 66
# Saving models
# Episode    74 | score: 400.0 | Avg_score:   47.43 | Time_steps:     400 | Learning_steps: 79
# Saving models
# Episode    75 | score:  86.0 | Avg_score:   47.93 | Time_steps:      86 | Learning_steps: 81
# Saving models
# Episode    76 | score: 286.0 | Avg_score:   51.03 | Time_steps:     286 | Learning_steps: 90
# Saving models
# Episode    77 | score: 162.0 | Avg_score:   52.45 | Time_steps:     162 | Learning_steps: 95
# Saving models
# Episode    78 | score: 125.0 | Avg_score:   53.37 | Time_steps:     125 | Learning_steps: 99
# Saving models
# Episode    79 | score:  54.0 | Avg_score:   53.38 | Time_steps:      54 | Learning_steps: 100
# Saving models
# Episode    80 | score: 124.0 | Avg_score:   54.25 | Time_steps:     124 | Learning_steps: 104
# Saving models
# Episode    81 | score:  81.0 | Avg_score:   54.57 | Time_steps:      81 | Learning_steps: 106
# Episode    82 | score:  39.0 | Avg_score:   54.39 | Time_steps:      39 | Learning_steps: 107
# Episode    83 | score:  60.0 | Avg_score:   54.45 | Time_steps:      60 | Learning_steps: 109
# Saving models
# Episode    84 | score:  90.0 | Avg_score:   54.87 | Time_steps:      90 | Learning_steps: 112
# Saving models
# Episode    85 | score: 180.0 | Avg_score:   56.33 | Time_steps:     180 | Learning_steps: 118
# Saving models
# Episode    86 | score: 136.0 | Avg_score:   57.24 | Time_steps:     136 | Learning_steps: 122
# Saving models
# Episode    87 | score: 159.0 | Avg_score:   58.40 | Time_steps:     159 | Learning_steps: 127
# Saving models
# Episode    88 | score: 306.0 | Avg_score:   61.18 | Time_steps:     306 | Learning_steps: 137
# Saving models
# Episode    89 | score: 327.0 | Avg_score:   64.13 | Time_steps:     327 | Learning_steps: 147
# Saving models
# Episode    90 | score: 216.0 | Avg_score:   65.80 | Time_steps:     216 | Learning_steps: 154
# Saving models
# Episode    91 | score: 362.0 | Avg_score:   69.02 | Time_steps:     362 | Learning_steps: 166
# Saving models
# Episode    92 | score: 202.0 | Avg_score:   70.45 | Time_steps:     202 | Learning_steps: 172
# Saving models
# Episode    93 | score: 217.0 | Avg_score:   72.01 | Time_steps:     217 | Learning_steps: 179
# Saving models
# Episode    94 | score: 151.0 | Avg_score:   72.84 | Time_steps:     151 | Learning_steps: 184
# Saving models
# Episode    95 | score: 255.0 | Avg_score:   74.74 | Time_steps:     255 | Learning_steps: 192
# Saving models
# Episode    96 | score: 500.0 | Avg_score:   79.12 | Time_steps:     500 | Learning_steps: 208
# Saving models
# Episode    97 | score: 500.0 | Avg_score:   83.42 | Time_steps:     500 | Learning_steps: 224
# Saving models
# Episode    98 | score: 500.0 | Avg_score:   87.63 | Time_steps:     500 | Learning_steps: 240
# Saving models
# Episode    99 | score: 500.0 | Avg_score:   91.75 | Time_steps:     500 | Learning_steps: 256
# Saving models
# Episode   100 | score: 500.0 | Avg_score:   95.79 | Time_steps:     500 | Learning_steps: 272
# Saving models
# Episode   101 | score: 500.0 | Avg_score:   99.75 | Time_steps:     500 | Learning_steps: 288
# Saving models
# Episode   102 | score: 500.0 | Avg_score:  103.64 | Time_steps:     500 | Learning_steps: 304
# Saving models
# Episode   103 | score: 500.0 | Avg_score:  107.45 | Time_steps:     500 | Learning_steps: 320
# Saving models
# Episode   104 | score: 500.0 | Avg_score:  111.19 | Time_steps:     500 | Learning_steps: 336
# Saving models
# Episode   105 | score: 193.0 | Avg_score:  111.96 | Time_steps:     193 | Learning_steps: 342
# Saving models
# Episode   106 | score: 444.0 | Avg_score:  115.07 | Time_steps:     444 | Learning_steps: 356
# Saving models
# Episode   107 | score: 500.0 | Avg_score:  118.63 | Time_steps:     500 | Learning_steps: 372
# Saving models
# Episode   108 | score: 500.0 | Avg_score:  122.13 | Time_steps:     500 | Learning_steps: 388
# Saving models
# Episode   109 | score: 500.0 | Avg_score:  125.56 | Time_steps:     500 | Learning_steps: 404
# Saving models
# Episode   110 | score: 500.0 | Avg_score:  128.94 | Time_steps:     500 | Learning_steps: 420
# Saving models
# Episode   111 | score: 500.0 | Avg_score:  132.25 | Time_steps:     500 | Learning_steps: 436
# Saving models
# Episode   112 | score: 500.0 | Avg_score:  135.50 | Time_steps:     500 | Learning_steps: 452
# Saving models
# Episode   113 | score: 500.0 | Avg_score:  138.70 | Time_steps:     500 | Learning_steps: 468
# Saving models
# Episode   114 | score: 500.0 | Avg_score:  141.84 | Time_steps:     500 | Learning_steps: 484
# Saving models
# Episode   115 | score: 500.0 | Avg_score:  144.93 | Time_steps:     500 | Learning_steps: 500
# Saving models
# Episode   116 | score: 500.0 | Avg_score:  147.97 | Time_steps:     500 | Learning_steps: 516
# Saving models
# Episode   117 | score: 315.0 | Avg_score:  149.38 | Time_steps:     315 | Learning_steps: 526
# Saving models
# Episode   118 | score: 240.0 | Avg_score:  150.14 | Time_steps:     240 | Learning_steps: 534
# Saving models
# Episode   119 | score: 158.0 | Avg_score:  150.21 | Time_steps:     158 | Learning_steps: 539
# Saving models
# Episode   120 | score: 160.0 | Avg_score:  150.29 | Time_steps:     160 | Learning_steps: 544
# Saving models
# Episode   121 | score: 176.0 | Avg_score:  150.50 | Time_steps:     176 | Learning_steps: 549
# Saving models
# Episode   122 | score: 257.0 | Avg_score:  151.37 | Time_steps:     257 | Learning_steps: 557
# Saving models
# Episode   123 | score: 297.0 | Avg_score:  152.54 | Time_steps:     297 | Learning_steps: 566
# Saving models
# Episode   124 | score: 298.0 | Avg_score:  153.70 | Time_steps:     298 | Learning_steps: 575
# Saving models
# Episode   125 | score: 500.0 | Avg_score:  156.45 | Time_steps:     500 | Learning_steps: 591
# Saving models
# Episode   126 | score: 500.0 | Avg_score:  159.16 | Time_steps:     500 | Learning_steps: 607
# Saving models
# Episode   127 | score: 500.0 | Avg_score:  161.82 | Time_steps:     500 | Learning_steps: 623
# Saving models
# Episode   128 | score: 500.0 | Avg_score:  164.44 | Time_steps:     500 | Learning_steps: 639
# Saving models
# Episode   129 | score: 500.0 | Avg_score:  167.02 | Time_steps:     500 | Learning_steps: 655
# Saving models
# Episode   130 | score: 495.0 | Avg_score:  169.53 | Time_steps:     495 | Learning_steps: 671
# Saving models
# Episode   131 | score: 500.0 | Avg_score:  172.03 | Time_steps:     500 | Learning_steps: 687
# Saving models
# Episode   132 | score: 500.0 | Avg_score:  174.50 | Time_steps:     500 | Learning_steps: 703
# Saving models
# Episode   133 | score: 500.0 | Avg_score:  176.93 | Time_steps:     500 | Learning_steps: 719
# Saving models
# Episode   134 | score: 500.0 | Avg_score:  179.32 | Time_steps:     500 | Learning_steps: 735
# Saving models
# Episode   135 | score: 500.0 | Avg_score:  181.68 | Time_steps:     500 | Learning_steps: 751
# Saving models
# Episode   136 | score: 500.0 | Avg_score:  184.00 | Time_steps:     500 | Learning_steps: 767
# Saving models
# Episode   137 | score: 500.0 | Avg_score:  186.29 | Time_steps:     500 | Learning_steps: 783
# Saving models
# Episode   138 | score: 500.0 | Avg_score:  188.55 | Time_steps:     500 | Learning_steps: 799
# Saving models
# Episode   139 | score: 500.0 | Avg_score:  190.77 | Time_steps:     500 | Learning_steps: 815
# Saving models
# Episode   140 | score: 500.0 | Avg_score:  192.96 | Time_steps:     500 | Learning_steps: 831
# Saving models
# Episode   141 | score: 500.0 | Avg_score:  195.13 | Time_steps:     500 | Learning_steps: 847
# Saving models
# Episode   142 | score: 500.0 | Avg_score:  197.26 | Time_steps:     500 | Learning_steps: 863
# Saving models
# Episode   143 | score: 500.0 | Avg_score:  199.36 | Time_steps:     500 | Learning_steps: 879
# Saving models
# Episode   144 | score: 500.0 | Avg_score:  201.43 | Time_steps:     500 | Learning_steps: 895
# Saving models
# Episode   145 | score: 500.0 | Avg_score:  203.48 | Time_steps:     500 | Learning_steps: 911
# Saving models
# Episode   146 | score: 500.0 | Avg_score:  205.50 | Time_steps:     500 | Learning_steps: 927
# Saving models
# Episode   147 | score: 500.0 | Avg_score:  207.49 | Time_steps:     500 | Learning_steps: 943
# Saving models
# Episode   148 | score: 500.0 | Avg_score:  209.45 | Time_steps:     500 | Learning_steps: 959
# Saving models
# Episode   149 | score: 500.0 | Avg_score:  211.39 | Time_steps:     500 | Learning_steps: 975
# Saving models
# Episode   150 | score: 500.0 | Avg_score:  213.30 | Time_steps:     500 | Learning_steps: 991
# Saving models
# Episode   151 | score: 500.0 | Avg_score:  215.18 | Time_steps:     500 | Learning_steps: 1007
# Saving models
# Episode   152 | score: 500.0 | Avg_score:  217.05 | Time_steps:     500 | Learning_steps: 1023
# Saving models
# Episode   153 | score: 500.0 | Avg_score:  218.88 | Time_steps:     500 | Learning_steps: 1039
# Saving models
# Episode   154 | score: 500.0 | Avg_score:  220.70 | Time_steps:     500 | Learning_steps: 1055
# Saving models
# Episode   155 | score: 500.0 | Avg_score:  222.49 | Time_steps:     500 | Learning_steps: 1071
# Saving models
# Episode   156 | score: 500.0 | Avg_score:  224.25 | Time_steps:     500 | Learning_steps: 1087
# Saving models
# Episode   157 | score: 500.0 | Avg_score:  226.00 | Time_steps:     500 | Learning_steps: 1103
# Saving models
# Episode   158 | score: 500.0 | Avg_score:  227.72 | Time_steps:     500 | Learning_steps: 1119
# Saving models
# Episode   159 | score: 500.0 | Avg_score:  229.43 | Time_steps:     500 | Learning_steps: 1135
# Saving models
# Episode   160 | score: 500.0 | Avg_score:  231.11 | Time_steps:     500 | Learning_steps: 1151
# Saving models
# Episode   161 | score: 500.0 | Avg_score:  232.77 | Time_steps:     500 | Learning_steps: 1167
# Saving models
# Episode   162 | score: 500.0 | Avg_score:  234.40 | Time_steps:     500 | Learning_steps: 1183
# Saving models
# Episode   163 | score: 500.0 | Avg_score:  236.02 | Time_steps:     500 | Learning_steps: 1199
# Saving models
# Episode   164 | score: 500.0 | Avg_score:  237.62 | Time_steps:     500 | Learning_steps: 1215
# Saving models
# Episode   165 | score: 500.0 | Avg_score:  239.20 | Time_steps:     500 | Learning_steps: 1231
# Saving models
# Episode   166 | score: 363.0 | Avg_score:  239.95 | Time_steps:     363 | Learning_steps: 1243
# Saving models
# Episode   167 | score: 500.0 | Avg_score:  241.49 | Time_steps:     500 | Learning_steps: 1259
# Saving models
# Episode   168 | score: 500.0 | Avg_score:  243.02 | Time_steps:     500 | Learning_steps: 1275
# Saving models
# Episode   169 | score: 500.0 | Avg_score:  244.54 | Time_steps:     500 | Learning_steps: 1291
# Saving models
# Episode   170 | score: 500.0 | Avg_score:  246.03 | Time_steps:     500 | Learning_steps: 1307
# Saving models
# Episode   171 | score: 500.0 | Avg_score:  247.51 | Time_steps:     500 | Learning_steps: 1323
# Saving models
# Episode   172 | score: 500.0 | Avg_score:  248.97 | Time_steps:     500 | Learning_steps: 1339
# Saving models
# Episode   173 | score: 500.0 | Avg_score:  250.41 | Time_steps:     500 | Learning_steps: 1355
# Saving models
# Episode   174 | score: 500.0 | Avg_score:  251.83 | Time_steps:     500 | Learning_steps: 1371
# Saving models
# Episode   175 | score: 500.0 | Avg_score:  253.24 | Time_steps:     500 | Learning_steps: 1387
# Saving models
# Episode   176 | score: 500.0 | Avg_score:  254.64 | Time_steps:     500 | Learning_steps: 1403
# Saving models
# Episode   177 | score: 500.0 | Avg_score:  256.02 | Time_steps:     500 | Learning_steps: 1419
# Saving models
# Episode   178 | score: 500.0 | Avg_score:  257.38 | Time_steps:     500 | Learning_steps: 1435
# Saving models
# Episode   179 | score: 500.0 | Avg_score:  258.73 | Time_steps:     500 | Learning_steps: 1451
# Saving models
# Episode   180 | score: 500.0 | Avg_score:  260.06 | Time_steps:     500 | Learning_steps: 1467
# Saving models
# Episode   181 | score: 500.0 | Avg_score:  261.38 | Time_steps:     500 | Learning_steps: 1483
# Saving models
# Episode   182 | score: 500.0 | Avg_score:  262.68 | Time_steps:     500 | Learning_steps: 1499
# Saving models
# Episode   183 | score: 500.0 | Avg_score:  263.97 | Time_steps:     500 | Learning_steps: 1515
# Saving models
# Episode   184 | score: 500.0 | Avg_score:  265.25 | Time_steps:     500 | Learning_steps: 1531
# Saving models
# Episode   185 | score: 500.0 | Avg_score:  266.51 | Time_steps:     500 | Learning_steps: 1547
# Saving models
# Episode   186 | score: 500.0 | Avg_score:  267.76 | Time_steps:     500 | Learning_steps: 1563
# Saving models
# Episode   187 | score: 500.0 | Avg_score:  268.99 | Time_steps:     500 | Learning_steps: 1579
# Saving models
# Episode   188 | score: 500.0 | Avg_score:  270.22 | Time_steps:     500 | Learning_steps: 1595
# Saving models
# Episode   189 | score: 500.0 | Avg_score:  271.43 | Time_steps:     500 | Learning_steps: 1611
# Saving models
# Episode   190 | score: 500.0 | Avg_score:  272.62 | Time_steps:     500 | Learning_steps: 1627
# Saving models
# Episode   191 | score: 500.0 | Avg_score:  273.81 | Time_steps:     500 | Learning_steps: 1643
# Saving models
# Episode   192 | score: 500.0 | Avg_score:  274.98 | Time_steps:     500 | Learning_steps: 1659
# Saving models
# Episode   193 | score: 500.0 | Avg_score:  276.14 | Time_steps:     500 | Learning_steps: 1675
# Saving models
# Episode   194 | score: 500.0 | Avg_score:  277.29 | Time_steps:     500 | Learning_steps: 1691
# Saving models
# Episode   195 | score: 500.0 | Avg_score:  278.42 | Time_steps:     500 | Learning_steps: 1707
# Saving models
# Episode   196 | score: 500.0 | Avg_score:  279.55 | Time_steps:     500 | Learning_steps: 1723
# Saving models
# Episode   197 | score: 500.0 | Avg_score:  280.66 | Time_steps:     500 | Learning_steps: 1739
# Saving models
# Episode   198 | score: 500.0 | Avg_score:  281.76 | Time_steps:     500 | Learning_steps: 1755
# Saving models
# Episode   199 | score: 500.0 | Avg_score:  282.86 | Time_steps:     500 | Learning_steps: 1771

# %%
agent.load_models()
agent.actor.eval()
agent.critic.eval()

n_games_eval = 5
max_time_steps = 2000
scores = []
# Evaluate

for i in range(n_games_eval):
    ovservation = env.reset()[0]
    done = False
    score = 0
    n_steps = 0
    while not done and n_steps < max_time_steps:
        n_steps += 1
        action, _, _ = agent.choose_action(ovservation)
        ovservation, reward, done, _, _ = env.step(action)
        score += reward
    scores.append(score)

np.mean(scores)
# Out:
# Loading models
# 2000.0
